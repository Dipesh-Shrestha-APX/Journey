# %%
print()

# %%
a = 10
print(f"Dipesh has {a} god nuggets", "This is the next section")
# Out:
# Dipesh has 10 god nuggets This is the next section

# %%
print(f"Dipesh has {a} god nuggets", "This is the next section", sep = "#", end ="---")
print("Instead of new line")
print("I am Dipesh Shrestha")
# Out:
# Dipesh has 10 god nuggets#This is the next section---Instead of new line
# I am Dipesh Shrestha

# %%
#DATA TYPES
print(1e308)
print(1e309) # Limited can't be used
print(True)
print([1,32,2]) # list
print((1,2,3)) # tuple
print(5+6j)
print("Wass up") # string
print({1,3,45}) # set
print({"a":"2", "b":"3"}) # dictionary | key value pairs
# Out:
# 1e+308
# inf
# True
# [1, 32, 2]
# (1, 2, 3)
# (5+6j)
# Wass up
# {1, 3, 45}
# {'a': '2', 'b': '3'}

# %%
diction = {"a":"2", "b":"3"}
type(diction)
# Out:
# dict

# %%
# Static and Dynamic typing
# default dynamic

a = 5
# int a = 5 Can't be used in python

a = 5
a = "Hello" # Dynmic binding
a,b,c = 1,2,3
d=e=f = 5
print(a,b,c,d,e,f)

# hello
# Out:
# 1 2 3 5 5 5
# ' hello\nthis is it'

# %%
a = input("Enter the number")
print(a)
# Out:
# Enter the number1
# 1

# %%
a = "123"
type(a)
a= int(a)
type(a)
# Out:
# int
