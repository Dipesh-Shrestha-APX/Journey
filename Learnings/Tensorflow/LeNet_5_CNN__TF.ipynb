# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
from keras.layers import Dense, Flatten, Conv2D, AveragePooling2D
from keras import Sequential
from keras.datasets import mnist

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = np.expand_dims(x_train, axis=-1).astype('float32') / 255.0
x_test = np.expand_dims(x_test, axis=-1).astype('float32') / 255.0

# %%
# x_train.shape
# x_test.shape
# x_train[0]

# %% [markdown]
# # LeNet Architecture

# %%
model = Sequential()
model.add(Conv2D(6, kernel_size=(5,5), padding='valid', activation='tanh', input_shape=(28,28,1)))
model.add(AveragePooling2D(pool_size=(2,2), strides=2, padding='valid'))
model.add(Conv2D(16, kernel_size=(5,5), padding='valid', activation='tanh'))
model.add(AveragePooling2D(pool_size=(2,2), strides=2, padding='valid'))
model.add(Flatten())
model.add(Dense(120, activation='tanh'))
model.add(Dense(84, activation='tanh'))
model.add(Dense(10, activation='softmax'))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_8 (Conv2D)               │ (None, 24, 24, 6)      │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_8             │ (None, 12, 12, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_9 (Conv2D)               │ (None, 8, 8, 16)       │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_9             │ (None, 4, 4, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ...

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=10, batch_size=32, validation_split=0.1)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 27s 15ms/step - accuracy: 0.8673 - loss: 0.4533 - val_accuracy: 0.9707 - val_loss: 0.0990
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 26s 16ms/step - accuracy: 0.9681 - loss: 0.1020 - val_accuracy: 0.9773 - val_loss: 0.0756
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 25s 15ms/step - accuracy: 0.9790 - loss: 0.0657 - val_accuracy: 0.9808 - val_loss: 0.0654
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 27s 16ms/step - accuracy: 0.9848 - loss: 0.0469 - val_accuracy: 0.9830 - val_loss: 0.0583
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 40s 15ms/step - accuracy: 0.9875 - loss: 0.0371 - val_accuracy: 0.9852 - val_loss: 0.0556
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 41s 15ms/step - accuracy: 0.9897 - loss: 0.0317 - val_accuracy: 0.9863 - val_loss: 0.0489
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 25s 15ms/step - accuracy: 0.9918 - loss: 0.0252 - val_accuracy: 0.9855 - val_loss: 0.0568
# Epoch 8/10
# ...

# %%
model.save("lenet5_model.keras")

# %%
predictions = model.predict(x_test)
# predictions[0]
predicted_class = np.argmax(predictions, axis=1)

# print("Predicted class:", predicted_class)
# print(predicted_class == y_test)
accuracy = tf.reduce_mean(tf.cast(predicted_class == y_test, tf.float32)).numpy()
print(f"Manual Accuracy: {accuracy * 100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step
# Manual Accuracy: 98.74%

# %%
predictions = model.predict(x_train)
# predictions[0]
predicted_class = np.argmax(predictions, axis=1)

# print("Predicted class:", predicted_class)
# print(predicted_class == y_test)
accuracy = tf.reduce_mean(tf.cast(predicted_class == y_train, tf.float32)).numpy()
print(f"Manual Accuracy: {accuracy * 100:.2f}%")
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step
# Manual Accuracy: 99.61%
